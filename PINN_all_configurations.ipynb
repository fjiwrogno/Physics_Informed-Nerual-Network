# %% [markdown]
# # 1. Input-output generator

# %%
! pip install control
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: control in c:\users\ivanf\appdata\roaming\python\python312\site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from control) (2.2.1)
# Requirement already satisfied: scipy>=1.8 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from control) (1.14.1)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from control) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->control) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->control) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->control) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->control) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->control) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->control) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->control) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->control) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ivanf\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->control) (1.17.0)

# %%
import control as ctrl
import math
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import joblib
import pickle

# %%
class DataGenerator:
    def __init__(
        self,
        n_config,           # select TF configuration
        sampling_rate=100,  # sampling of the signals
        time_length=9,      # length of the simulation (no leading 0)
        initial_zero=1,     # length in seconds of initial 0
        fixed_period_n=True,
    ):
        # store values
        self.sampling_freq = 1 / sampling_rate
        self.time_length = time_length
        self.initial_zero = initial_zero
        self.fixed_period_n = fixed_period_n

        # select configuration
        s = ctrl.tf('s')
        if n_config == 0:
            self.G = 2**2 / (s**2 + 2*0.3*2*s + 2**2)
        # Update __init__ method for Config 1
        elif n_config == 1:
            self.G1 = 2**2 / (s**2 + 2*0.3*2*s + 2**2)  # First system
            self.G2 = 7**2 / (s**2 + 2*0.6*7*s + 7**2)  # Second system
            self.G = self.G1 + self.G2  # Combined transfer function

        elif n_config == 2:
            self.G = (s**2 - 3*s - 4) / (s**2 + 5*s + 6)
        else:
            raise Exception("Invalid configuration number")

        print(f"TF: {self.G}")

    def get_differential_eq(self, n_config):
        """
        Return the components of the differential equation for the selected transfer function configuration.
        """
        if n_config == 0:
            # Single transfer function
            return {
                'coeffs_y': [1, 1.2, 4],  # Coefficients of [d^2y/dt^2, dy/dt, y]
                'coeffs_u': [4],         # Coefficients of u(t)
            }
        elif n_config == 1:
            # Multiple transfer functions
            return {
                'system_1': {
                    'coeffs_y': [1, 1.2, 4],  # System 1 coefficients
                    'coeffs_u': [4],
                },
                'system_2': {
                    'coeffs_y': [1, 8.4, 49],  # System 2 coefficients
                    'coeffs_u': [49],
                },
            }
        elif n_config == 2:
            # Complex transfer function
            return {
                'coeffs_y': [1, 5, 6],          # Coefficients of [d^2y/dt^2, dy/dt, y]
                'coeffs_u': [1, -3, -4],       # Coefficients of [d^2u/dt^2, du/dt, u]
            }

    def sine_wave_response(self, freq, silent=True):
        return self.response(0, freq, float('NaN'), silent)

    def impulse_response(self, ampl=10, silent=True):
        return self.response(1, float('NaN'), ampl, silent)

    def response(self, type, freq, ampl, silent=True):
        """
        Generate a response (sine wave or impulse) based on the given parameters.
        """
        t_zero = np.arange(0, self.initial_zero, self.sampling_freq)
        t_sim = np.arange(self.initial_zero, self.initial_zero + self.time_length, self.sampling_freq)
    
        if type == 0 and self.fixed_period_n:
            time_period = 1 / freq
            periods_n = self.time_length / time_period
            remaining_period_fraction = periods_n - math.floor(periods_n)
            if not math.isclose(remaining_period_fraction, 0, abs_tol=1e-4):
                missing_part = (1 - remaining_period_fraction) * time_period
                t_addition = np.arange(
                    self.initial_zero + self.time_length,
                    self.initial_zero + self.time_length + missing_part,
                    self.sampling_freq,
                )
                t_sim = np.hstack((t_sim, t_addition))
    
        t = np.hstack((t_zero, t_sim))
    
        leading_zero = np.zeros(len(t_zero), dtype=float)
        if type == 0:
            input_signal = np.sin(2 * np.pi * freq * (t_sim - self.initial_zero))
        elif type == 1:
            input_signal = np.zeros_like(t_sim)
            input_signal[0] = ampl
        else:
            raise Exception("Invalid response type")
        u = np.hstack((leading_zero, input_signal))
    
        # Handle Config 1 (Two Systems)
        if hasattr(self, 'G1') and hasattr(self, 'G2'):
            # Simulate G1 and G2 separately
            t_resp1, y1 = ctrl.forced_response(self.G1, T=t, U=u)
            t_resp2, y2 = ctrl.forced_response(self.G2, T=t, U=u)
            y = y1 + y2  # Total response
        else:
            t_resp, y = ctrl.forced_response(self.G, T=t, U=u)
            y1, y2 = None, None  # Not applicable for Config 0 or Config 2
    
        if not silent:
            plt.figure()
            plt.plot(t, y, label="output (y)")
            if y1 is not None and y2 is not None:
                plt.plot(t, y1, label="output (y1)", linestyle="--")
                plt.plot(t, y2, label="output (y2)", linestyle="-.")
            if type != 1:
                plt.plot(t, u, label="input (u)", linestyle=":")
            plt.legend()
    
        return {'time': t, 'input': u, 'response': y, 'response_1': y1, 'response_2': y2}

# %% [markdown]
# # 2. PINN

# %% [markdown]
# ## 2.1: Define the Physics-Based Loss Function

# %%
def physics_loss(t, y_dict, u, config, coeffs_y, coeffs_u):
    """
    Compute the physics loss based on the configuration and differential equations.
    """
    if config == 0:
        # Single equation
        residual = (
            coeffs_y[0] * y_dict['y_ddot'] + coeffs_y[1] * y_dict['y_dot'] + coeffs_y[2] * y_dict['y']
            - coeffs_u[0] * u
        )
        return torch.mean(residual**2)
    
    elif config == 1:
        # Two systems
        # Residual for System 1
        residual_1 = (
            coeffs_y['system_1'][0] * y_dict['y1_ddot']
            + coeffs_y['system_1'][1] * y_dict['y1_dot']
            + coeffs_y['system_1'][2] * y_dict['y1']
            - coeffs_u['system_1'][0] * u
        )
        
        # Residual for System 2
        residual_2 = (
            coeffs_y['system_2'][0] * y_dict['y2_ddot']
            + coeffs_y['system_2'][1] * y_dict['y2_dot']
            + coeffs_y['system_2'][2] * y_dict['y2']
            - coeffs_u['system_2'][0] * u
        )
        
        # Total physics loss
        return torch.mean(residual_1**2) + torch.mean(residual_2**2)
    
    elif config == 2:
        # Complex equation
        residual = (
            coeffs_y[0] * y_dict['y_ddot']
            + coeffs_y[1] * y_dict['y_dot']
            + coeffs_y[2] * y_dict['y']
            - (coeffs_u[0] * y_dict['u_ddot'] + coeffs_u[1] * y_dict['u_dot'] + coeffs_u[2] * u)
        )
        return torch.mean(residual**2)
    
    else:
        raise ValueError("Invalid configuration")
        
def data_loss(y_pred, y_true):
    return torch.mean((y_pred - y_true)**2)

def boundary_loss(config, y0_pred, y0_true, y0_dot_pred, y0_dot_true):
    if config == 0 or config == 2:
        return torch.mean((y0_pred - y0_true)**2) + torch.mean((y0_dot_pred - y0_dot_true)**2)
    
    elif config == 1:
        return (
            torch.mean((y0_pred['system_1'] - y0_true['system_1'])**2)
            + torch.mean((y0_dot_pred['system_1'] - y0_dot_true['system_1'])**2)
            + torch.mean((y0_pred['system_2'] - y0_true['system_2'])**2)
            + torch.mean((y0_dot_pred['system_2'] - y0_dot_true['system_2'])**2)
        )
    else:
        raise ValueError("Invalid configuration")

def total_loss(
    t,
    y_dict,
    u,
    config,
    coeffs_y,
    coeffs_u,
    y_true=None,
    y0_pred=None,
    y0_true=None,
    y0_dot_pred=None,
    y0_dot_true=None,
    lambdas=(1.0, 1.0, 1.0),
):
    """
    Compute the total loss as a weighted sum of physics, data, and boundary losses.
    """
    lambda1, lambda2, lambda3 = lambdas

    # Physics loss
    L_physics = physics_loss(t, y_dict, u, config, coeffs_y, coeffs_u)

    # Data loss (if true data is provided)
    if config == 1:
        # For Config 1, compute data loss for y1 and y2 separately
        L_data = (
            data_loss(y_dict['y1'], y_true['y1'])
            + data_loss(y_dict['y2'], y_true['y2'])
            if y_true is not None
            else 0.0
        )
    else:
        # For Config 0 and Config 2, use 'y'
        L_data = data_loss(y_dict['y'], y_true) if y_true is not None else 0.0

    # Boundary loss (if initial conditions are provided)
    L_boundary = (
        boundary_loss(config, y0_pred, y0_true, y0_dot_pred, y0_dot_true)
        if y0_true is not None
        else 0.0
    )

    return lambda1 * L_physics + lambda2 * L_data + lambda3 * L_boundary

# %% [markdown]
# ## 2.2: Build the Neural Network

# %%
class PINN(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_size, num_layers):
        super(PINN, self).__init__()
        layers = []
        layers.append(nn.Linear(input_dim, hidden_size))
        layers.append(nn.Tanh())
        for _ in range(num_layers - 1):
            layers.append(nn.Linear(hidden_size, hidden_size))
            layers.append(nn.Tanh())
        layers.append(nn.Linear(hidden_size, output_dim))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## 2.3 Dataset

# %%
min_f, max_f, step_f = 1, 10, 0.05
train_freq = np.arange(min_f, max_f + step_f, step_f)
val_freq = np.arange(min_f + step_f / 2, max_f + step_f, step_f * 4)
test_freq = np.arange(min_f + 3 * step_f / 2, max_f + step_f, step_f * 4)

# %%
def create_pinn_dataset(data_generator, frequencies, label):
    dataset = []
    for freq in frequencies:
        data = data_generator.sine_wave_response(freq)
        t = data['time']
        u = data['input']
        y = data['response']
        
        # For Config 1, include y1 and y2
        y1 = data.get('response_1', None)
        y2 = data.get('response_2', None)

        # Compute derivatives
        y_dot = np.gradient(y, t)
        y_ddot = np.gradient(y_dot, t)
        u_dot = np.gradient(u, t)
        u_ddot = np.gradient(u_dot, t)

        # Compute derivatives for y1 and y2 if available
        y1_dot = np.gradient(y1, t) if y1 is not None else None
        y1_ddot = np.gradient(y1_dot, t) if y1_dot is not None else None
        y2_dot = np.gradient(y2, t) if y2 is not None else None
        y2_ddot = np.gradient(y2_dot, t) if y2_dot is not None else None

        # Combine into a single dataset
        dataset_entry = {
            't': t,
            'u': u,
            'y': y,
            'y_dot': y_dot,
            'y_ddot': y_ddot,
            'u_dot': u_dot,
            'u_ddot': u_ddot,
        }

        # Add y1 and y2 if available
        if y1 is not None and y2 is not None:
            dataset_entry.update({
                'y1': y1,
                'y1_dot': y1_dot,
                'y1_ddot': y1_ddot,
                'y2': y2,
                'y2_dot': y2_dot,
                'y2_ddot': y2_ddot,
            })

        dataset.append(dataset_entry)
    #print(f"{label} dataset created with {len(dataset)} samples.")
    return dataset

# %%
def create_and_save_pinn_datasets(configs, train_freq, val_freq, test_freq):
    for config in configs:
        # Initialize DataGenerator for each configuration
        data_generator = DataGenerator(config, sampling_rate=100, time_length=10, initial_zero=2)
        
        # Generate datasets
        train_dataset = create_pinn_dataset(data_generator, train_freq, f"Train (Config {config})")
        val_dataset = create_pinn_dataset(data_generator, val_freq, f"Validation (Config {config})")
        test_dataset = create_pinn_dataset(data_generator, test_freq, f"Test (Config {config})")
        
        # Save datasets to pickle files
        filename_prefix = f"pinn_config{config}"
        with open(f"{filename_prefix}_train.pkl", "wb") as f:
            pickle.dump(train_dataset, f)
        with open(f"{filename_prefix}_val.pkl", "wb") as f:
            pickle.dump(val_dataset, f)
        with open(f"{filename_prefix}_test.pkl", "wb") as f:
            pickle.dump(test_dataset, f)

        #print(f"Datasets for Config {config} saved as {filename_prefix}_*.pkl")

# Frequency sets
min_f, max_f, step_f = 1, 10, 0.05
train_freq = np.arange(min_f, max_f + step_f, step_f)
val_freq = np.arange(min_f + step_f / 2, max_f + step_f, step_f * 4)
test_freq = np.arange(min_f + 3 * step_f / 2, max_f + step_f, step_f * 4)

# Create datasets for configurations 0, 1, 2
create_and_save_pinn_datasets([0, 1, 2], train_freq, val_freq, test_freq)
# Out:
# TF: <TransferFunction>: sys[2854]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#        4
# ---------------
# s^2 + 1.2 s + 4
#
# TF: <TransferFunction>: sys[3147]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#          53 s^2 + 92.4 s + 392
# ----------------------------------------
# s^4 + 9.6 s^3 + 63.08 s^2 + 92.4 s + 196
#
# TF: <TransferFunction>: sys[3709]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# s^2 - 3 s - 4
# -------------
# s^2 + 5 s + 6

# %%
# Function to load a dataset
def load_pinn_dataset(config):
    filename_prefix = f"pinn_config{config}"
    with open(f"{filename_prefix}_train.pkl", "rb") as f:
        train_dataset = pickle.load(f)
    with open(f"{filename_prefix}_val.pkl", "rb") as f:
        val_dataset = pickle.load(f)
    with open(f"{filename_prefix}_test.pkl", "rb") as f:
        test_dataset = pickle.load(f)
    return train_dataset, val_dataset, test_dataset

# %% [markdown]
# # 3. Training

# %%
# Training loop for all configurations
configs = [0, 1, 2]
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialize loss history
loss_history = {config: [] for config in configs}

for config in configs:
    print(f"\n=== Training for Config {config} ===")

    # Load dataset
    train_dataset, val_dataset, test_dataset = load_pinn_dataset(config)

    # Initialize DataGenerator and retrieve coefficients
    data_generator = DataGenerator(config, sampling_rate=100, time_length=10, initial_zero=2)
    coefficients = data_generator.get_differential_eq(config)

    # Initialize PINN
    input_dim = 2  # [t, u]
    output_dim = 2 if config == 1 else 1  # [y1, y2] for Config 1, otherwise [y]
    pinn = PINN(input_dim=input_dim, output_dim=output_dim, hidden_size=50, num_layers=4).to(device)

    optimizer = torch.optim.Adam(pinn.parameters(), lr=1e-3)

    best_loss = float('inf')
    best_model_state = None

    # Define the parameters that rely on the configuration

    if config == 0:
        num_epochs = 10000
        lambdas = (0.9, 0.0, 0.1)
        coeffs_y = coefficients['coeffs_y']
        coeffs_u = coefficients['coeffs_u']

    elif config == 1:
        num_epochs = 30000
        lambdas = (0.75, 0.15, 0.1)
        coeffs_y = {
            'system_1': coefficients['system_1']['coeffs_y'],
            'system_2': coefficients['system_2']['coeffs_y'],
        }
        coeffs_u = {
            'system_1': coefficients['system_1']['coeffs_u'],
            'system_2': coefficients['system_2']['coeffs_u'],
        }
    elif config == 2:
        num_epochs = 20000
        lambdas = (0.9, 0, 0.1)
        coeffs_y = coefficients['coeffs_y']
        coeffs_u = coefficients['coeffs_u']

    for epoch in range(num_epochs):
        optimizer.zero_grad()

        # Fetch a sample from the training dataset
        sample = train_dataset[0]
        t = torch.tensor(sample['t'], requires_grad=True, dtype=torch.float32).to(device)
        u = torch.tensor(sample['u'], dtype=torch.float32).to(device)

        if config == 1:
            # For Config 1, y_true contains y1 and y2
            y_true = {
                'y1': torch.tensor(sample['y1'], dtype=torch.float32).to(device),
                'y2': torch.tensor(sample['y2'], dtype=torch.float32).to(device),
            }
        else:
            # For Config 0 and Config 2, y_true contains y
            y_true = torch.tensor(sample['y'], dtype=torch.float32).to(device)

        # Forward pass
        inputs = torch.cat((t.unsqueeze(1), u.unsqueeze(1)), dim=1)
        outputs = pinn(inputs)

        # Prepare y_dict
        if config == 0:
            y_dict = {
                'y': outputs[:, 0],
                'y_dot': torch.tensor(sample['y_dot'], dtype=torch.float32).to(device),
                'y_ddot': torch.tensor(sample['y_ddot'], dtype=torch.float32).to(device),
            }

        elif config == 1:
            y_dict = {
                'y1': outputs[:, 0],
                'y1_dot': torch.tensor(sample['y1_dot'], dtype=torch.float32).to(device),
                'y1_ddot': torch.tensor(sample['y1_ddot'], dtype=torch.float32).to(device),
                'y2': outputs[:, 1],
                'y2_dot': torch.tensor(sample['y2_dot'], dtype=torch.float32).to(device),
                'y2_ddot': torch.tensor(sample['y2_ddot'], dtype=torch.float32).to(device),
            }
        elif config == 2:
            y_dict = {
                'y': outputs[:, 0],
                'y_dot': torch.tensor(sample['y_dot'], dtype=torch.float32).to(device),
                'y_ddot': torch.tensor(sample['y_ddot'], dtype=torch.float32).to(device),
                'u_dot': torch.tensor(sample['u_dot'], dtype=torch.float32).to(device),
                'u_ddot': torch.tensor(sample['u_ddot'], dtype=torch.float32).to(device),
            }

        # Compute Total Loss
        total_loss_value = total_loss(
            t=t,
            y_dict=y_dict,
            u=u,
            config=config,
            coeffs_y=coeffs_y,
            coeffs_u=coeffs_u,
            y_true=y_true,
            lambdas=lambdas,
        )

        # Backpropagation
        total_loss_value.backward()
        optimizer.step()

        # Track the best model
        if total_loss_value.item() < best_loss:
            best_loss = total_loss_value.item()
            best_model_state = pinn.state_dict()

        # Log the loss value
        loss_history[config].append(total_loss_value.item())

        # Logging
        if epoch % 100 == 0:
            print(f"Config {config}, Epoch {epoch}, Total Loss: {total_loss_value.item():.6f}")

    # Save the best model for the current configuration
    torch.save(best_model_state, f"pinn_config{config}_best_model.pth")
    print(f"Best model for Config {config} saved with loss: {best_loss:.6f}")
# Out:
# === Training for Config 0 ===
# TF: <TransferFunction>: sys[4093]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#        4
# ---------------
# s^2 + 1.2 s + 4
#
# Config 0, Epoch 0, Total Loss: 0.152384
# Config 0, Epoch 100, Total Loss: 0.045999
# Config 0, Epoch 200, Total Loss: 0.039677
# Config 0, Epoch 300, Total Loss: 0.045417
# Config 0, Epoch 400, Total Loss: 0.027423
# Config 0, Epoch 500, Total Loss: 0.023263
# Config 0, Epoch 600, Total Loss: 0.019695
# Config 0, Epoch 700, Total Loss: 0.021515
# Config 0, Epoch 800, Total Loss: 0.014456
# Config 0, Epoch 900, Total Loss: 0.012675
# Config 0, Epoch 1000, Total Loss: 0.012632
# Config 0, Epoch 1100, Total Loss: 0.011236
# Config 0, Epoch 1200, Total Loss: 0.010447
# Config 0, Epoch 1300, Total Loss: 0.009760
# Config 0, Epoch 1400, Total Loss: 0.009795
# Config 0, Epoch 1500, Total Loss: 0.009098
# Config 0, Epoch 1600, Total Loss: 0.008641
# Config 0, Epoch 1700, Total Loss: 0.008218
# Config 0, Epoch 1800, Total Loss: 0.025111
# Config 0, Epoch 1900, Total Loss: 0.007806
# Config 0, Epoch 2000, Total Loss: 0.007477
# Config 0, Epoch 2100, Total Loss: 0.007183
# Config 0, Epoch 2200, Total Loss: 0.006911
# Config 0, Epoch 2300, Total Loss: 0.007163
# Config 0, Epoch 2400, Total Loss: 0.006768
# Config 0, Epoch 2500, Total Loss: 0.006559
# Config 0, Epoch 2600, Total Loss: 0.006372
# Config 0, Epoch 2700, Total Loss: 0.006196
# Config 0, Epoch 2800, Total Loss: 0.006022
# Config 0, Epoch 2900, Total Loss: 0.006075
# Config 0, Epoch 3000, Total Loss: 0.005863
# Config 0, Epoch 3100, Total Loss: 0.005647
# Config 0, Epoch 3200, Total Loss: 0.005374
# Config 0, Epoch 3300, Total Loss: 0.004990
# Config 0, Epoch 3400, Total Loss: 0.004629
# Config 0, Epoch 3500, Total Loss: 0.004114
# Config 0, Epoch 3600, Total Loss: 0.003795
# Config 0, Epoch 3700, Total Loss: 0.003611
# Config 0, Epoch 3800, Total Loss: 0.003482
# Config 0, Epoch 3900, Total Loss: 0.003379
# Config 0, Epoch 4000, Total Loss: 0.003301
# Config 0, Epoch 4100, Total Loss: 0.003231
# Config 0, Epoch 4200, Total Loss: 0.003181
# Config 0, Epoch 4300, Total Loss: 0.003146
# Config 0, Epoch 4400, Total Loss: 0.003117
# Config 0, Epoch 4500, Total Loss: 0.003095
# Config 0, Epoch 4600, Total Loss: 0.003097
# Config 0, Epoch 4700, Total Loss: 0.003077
# Config 0, Epoch 4800, Total Loss: 0.003064
# Config 0, Epoch 4900, Total Loss: 0.003053
# Config 0, Epoch 5000, Total Loss: 0.003043
# Config 0, Epoch 5100, Total Loss: 0.003069
# Config 0, Epoch 5200, Total Loss: 0.003038
# Config 0, Epoch 5300, Total Loss: 0.003028
# Config 0, Epoch 5400, Total Loss: 0.003019
# Config 0, Epoch 5500, Total Loss: 0.003011
# Config 0, Epoch 5600, Total Loss: 0.003032
# Config 0, Epoch 5700, Total Loss: 0.003006
# Config 0, Epoch 5800, Total Loss: 0.002998
# Config 0, Epoch 5900, Total Loss: 0.002990
# Config 0, Epoch 6000, Total Loss: 0.004247
# Config 0, Epoch 6100, Total Loss: 0.002988
# Config 0, Epoch 6200, Total Loss: 0.002980
# Config 0, Epoch 6300, Total Loss: 0.002973
# Config 0, Epoch 6400, Total Loss: 0.002966
# Config 0, Epoch 6500, Total Loss: 0.003075
# Config 0, Epoch 6600, Total Loss: 0.002966
# Config 0, Epoch 6700, Total Loss: 0.002959
# Config 0, Epoch 6800, Total Loss: 0.002952
# Config 0, Epoch 6900, Total Loss: 0.002946
# Config 0, Epoch 7000, Total Loss: 0.003105
# Config 0, Epoch 7100, Total Loss: 0.002938
# Config 0, Epoch 7200, Total Loss: 0.002939
# Config 0, Epoch 7300, Total Loss: 0.002933
# Config 0, Epoch 7400, Total Loss: 0.002928
# Config 0, Epoch 7500, Total Loss: 0.002933
# Config 0, Epoch 7600, Total Loss: 0.002926
# Config 0, Epoch 7700, Total Loss: 0.002920
# Config 0, Epoch 7800, Total Loss: 0.006322
# Config 0, Epoch 7900, Total Loss: 0.002913
# Config 0, Epoch 8000, Total Loss: 0.002907
# Config 0, Epoch 8100, Total Loss: 0.002917
# Config 0, Epoch 8200, Total Loss: 0.002906
# Config 0, Epoch 8300, Total Loss: 0.002899
# Config 0, Epoch 8400, Total Loss: 0.002893
# Config 0, Epoch 8500, Total Loss: 0.002898
# Config 0, Epoch 8600, Total Loss: 0.002889
# Config 0, Epoch 8700, Total Loss: 0.002882
# Config 0, Epoch 8800, Total Loss: 0.003786
# Config 0, Epoch 8900, Total Loss: 0.002875
# Config 0, Epoch 9000, Total Loss: 0.002865
# Config 0, Epoch 9100, Total Loss: 0.003009
# Config 0, Epoch 9200, Total Loss: 0.002857
# Config 0, Epoch 9300, Total Loss: 0.002844
# Config 0, Epoch 9400, Total Loss: 0.003094
# Config 0, Epoch 9500, Total Loss: 0.002833
# Config 0, Epoch 9600, Total Loss: 0.002813
# Config 0, Epoch 9700, Total Loss: 0.002790
# Config 0, Epoch 9800, Total Loss: 0.002789
# Config 0, Epoch 9900, Total Loss: 0.002760
# Best model for Config 0 saved with loss: 0.002728
#
# === Training for Config 1 ===
# TF: <TransferFunction>: sys[4114]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#          53 s^2 + 92.4 s + 392
# ----------------------------------------
# s^4 + 9.6 s^3 + 63.08 s^2 + 92.4 s + 196
#
# Config 1, Epoch 0, Total Loss: 615.079102
# Config 1, Epoch 100, Total Loss: 582.411621
# Config 1, Epoch 200, Total Loss: 581.548828
# Config 1, Epoch 300, Total Loss: 581.342712
# Config 1, Epoch 400, Total Loss: 581.235229
# Config 1, Epoch 500, Total Loss: 581.144714
# Config 1, Epoch 600, Total Loss: 581.087708
# Config 1, Epoch 700, Total Loss: 580.987366
# Config 1, Epoch 800, Total Loss: 580.950989
# Config 1, Epoch 900, Total Loss: 580.866394
# Config 1, Epoch 1000, Total Loss: 580.858398
# Config 1, Epoch 1100, Total Loss: 580.761169
# Config 1, Epoch 1200, Total Loss: 580.875244
# Config 1, Epoch 1300, Total Loss: 580.661499
# Config 1, Epoch 1400, Total Loss: 580.504395
# Config 1, Epoch 1500, Total Loss: 580.697510
# Config 1, Epoch 1600, Total Loss: 580.411377
# Config 1, Epoch 1700, Total Loss: 580.179260
# Config 1, Epoch 1800, Total Loss: 580.794739
# Config 1, Epoch 1900, Total Loss: 580.091064
# Config 1, Epoch 2000, Total Loss: 579.785645
# Config 1, Epoch 2100, Total Loss: 579.448975
# Config 1, Epoch 2200, Total Loss: 579.629211
# Config 1, Epoch 2300, Total Loss: 579.272095
# Config 1, Epoch 2400, Total Loss: 579.013489
# Config 1, Epoch 2500, Total Loss: 579.484497
# Config 1, Epoch 2600, Total Loss: 578.782776
# Config 1, Epoch 2700, Total Loss: 578.626648
# Config 1, Epoch 2800, Total Loss: 578.773743
# Config 1, Epoch 2900, Total Loss: 578.491272
# Config 1, Epoch 3000, Total Loss: 578.398682
# Config 1, Epoch 3100, Total Loss: 579.911011
# Config 1, Epoch 3200, Total Loss: 577.890808
# Config 1, Epoch 3300, Total Loss: 577.265869
# Config 1, Epoch 3400, Total Loss: 575.581299
# Config 1, Epoch 3500, Total Loss: 572.166199
# Config 1, Epoch 3600, Total Loss: 568.132385
# Config 1, Epoch 3700, Total Loss: 562.872253
# Config 1, Epoch 3800, Total Loss: 554.033325
# Config 1, Epoch 3900, Total Loss: 527.765625
# Config 1, Epoch 4000, Total Loss: 514.553589
# Config 1, Epoch 4100, Total Loss: 506.628876
# Config 1, Epoch 4200, Total Loss: 489.202698
# Config 1, Epoch 4300, Total Loss: 479.833466
# Config 1, Epoch 4400, Total Loss: 473.313446
# Config 1, Epoch 4500, Total Loss: 464.886597
# Config 1, Epoch 4600, Total Loss: 458.900330
# Config 1, Epoch 4700, Total Loss: 452.274841
# Config 1, Epoch 4800, Total Loss: 448.758759
# Config 1, Epoch 4900, Total Loss: 444.776672
# Config 1, Epoch 5000, Total Loss: 441.141296
# Config 1, Epoch 5100, Total Loss: 438.220123
# Config 1, Epoch 5200, Total Loss: 434.560669
# Config 1, Epoch 5300, Total Loss: 481.732971
# Config 1, Epoch 5400, Total Loss: 426.974304
# Config 1, Epoch 5500, Total Loss: 422.580353
# Config 1, Epoch 5600, Total Loss: 417.530579
# Config 1, Epoch 5700, Total Loss: 412.079620
# Config 1, Epoch 5800, Total Loss: 406.671082
# Config 1, Epoch 5900, Total Loss: 400.845032
# Config 1, Epoch 6000, Total Loss: 394.805939
# Config 1, Epoch 6100, Total Loss: 389.846619
# Config 1, Epoch 6200, Total Loss: 385.254791
# Config 1, Epoch 6300, Total Loss: 381.675446
# Config 1, Epoch 6400, Total Loss: 374.651123
# Config 1, Epoch 6500, Total Loss: 368.964020
# Config 1, Epoch 6600, Total Loss: 362.126160
# Config 1, Epoch 6700, Total Loss: 354.188263
# Config 1, Epoch 6800, Total Loss: 346.607910
# Config 1, Epoch 6900, Total Loss: 340.305145
# Config 1, Epoch 7000, Total Loss: 336.049042
# Config 1, Epoch 7100, Total Loss: 331.937378
# Config 1, Epoch 7200, Total Loss: 323.956604
# Config 1, Epoch 7300, Total Loss: 319.437683
# Config 1, Epoch 7400, Total Loss: 315.097626
# Config 1, Epoch 7500, Total Loss: 311.036560
# Config 1, Epoch 7600, Total Loss: 307.287659
# Config 1, Epoch 7700, Total Loss: 303.249847
# Config 1, Epoch 7800, Total Loss: 298.781525
# Config 1, Epoch 7900, Total Loss: 300.870728
# Config 1, Epoch 8000, Total Loss: 287.755157
# Config 1, Epoch 8100, Total Loss: 279.440002
# Config 1, Epoch 8200, Total Loss: 270.177307
# Config 1, Epoch 8300, Total Loss: 263.934845
# Config 1, Epoch 8400, Total Loss: 259.191071
# Config 1, Epoch 8500, Total Loss: 252.602753
# Config 1, Epoch 8600, Total Loss: 245.498169
# Config 1, Epoch 8700, Total Loss: 239.786331
# Config 1, Epoch 8800, Total Loss: 238.096619
# Config 1, Epoch 8900, Total Loss: 232.052979
# Config 1, Epoch 9000, Total Loss: 231.631653
# Config 1, Epoch 9100, Total Loss: 222.836121
# Config 1, Epoch 9200, Total Loss: 215.540482
# Config 1, Epoch 9300, Total Loss: 207.635925
# Config 1, Epoch 9400, Total Loss: 201.395660
# Config 1, Epoch 9500, Total Loss: 199.312012
# Config 1, Epoch 9600, Total Loss: 197.022873
# Config 1, Epoch 9700, Total Loss: 194.923172
# Config 1, Epoch 9800, Total Loss: 193.231216
# Config 1, Epoch 9900, Total Loss: 191.075775
# Config 1, Epoch 10000, Total Loss: 189.402817
# Config 1, Epoch 10100, Total Loss: 186.930496
# Config 1, Epoch 10200, Total Loss: 185.920898
# Config 1, Epoch 10300, Total Loss: 183.098038
# Config 1, Epoch 10400, Total Loss: 181.203751
# Config 1, Epoch 10500, Total Loss: 180.167709
# Config 1, Epoch 10600, Total Loss: 178.796875
# Config 1, Epoch 10700, Total Loss: 177.606140
# Config 1, Epoch 10800, Total Loss: 186.128571
# Config 1, Epoch 10900, Total Loss: 175.710175
# Config 1, Epoch 11000, Total Loss: 174.646011
# Config 1, Epoch 11100, Total Loss: 174.275101
# Config 1, Epoch 11200, Total Loss: 172.663239
# Config 1, Epoch 11300, Total Loss: 171.425461
# Config 1, Epoch 11400, Total Loss: 170.788376
# Config 1, Epoch 11500, Total Loss: 168.959702
# Config 1, Epoch 11600, Total Loss: 167.146637
# Config 1, Epoch 11700, Total Loss: 166.578247
# Config 1, Epoch 11800, Total Loss: 162.812119
# Config 1, Epoch 11900, Total Loss: 176.209061
# Config 1, Epoch 12000, Total Loss: 157.336685
# Config 1, Epoch 12100, Total Loss: 153.597214
# Config 1, Epoch 12200, Total Loss: 151.678024
# Config 1, Epoch 12300, Total Loss: 148.229736
# Config 1, Epoch 12400, Total Loss: 145.747086
# Config 1, Epoch 12500, Total Loss: 146.876251
# Config 1, Epoch 12600, Total Loss: 142.975708
# Config 1, Epoch 12700, Total Loss: 141.778519
# Config 1, Epoch 12800, Total Loss: 140.692947
# Config 1, Epoch 12900, Total Loss: 139.934021
# Config 1, Epoch 13000, Total Loss: 138.894913
# Config 1, Epoch 13100, Total Loss: 137.842941
# Config 1, Epoch 13200, Total Loss: 137.040955
# Config 1, Epoch 13300, Total Loss: 135.824326
# Config 1, Epoch 13400, Total Loss: 134.533951
# Config 1, Epoch 13500, Total Loss: 145.841019
# Config 1, Epoch 13600, Total Loss: 132.026810
# Config 1, Epoch 13700, Total Loss: 130.441299
# Config 1, Epoch 13800, Total Loss: 148.670135
# Config 1, Epoch 13900, Total Loss: 127.483627
# Config 1, Epoch 14000, Total Loss: 125.645912
# Config 1, Epoch 14100, Total Loss: 138.441544
# Config 1, Epoch 14200, Total Loss: 122.598915
# Config 1, Epoch 14300, Total Loss: 120.775627
# Config 1, Epoch 14400, Total Loss: 203.814255
# Config 1, Epoch 14500, Total Loss: 118.353661
# Config 1, Epoch 14600, Total Loss: 116.933922
# Config 1, Epoch 14700, Total Loss: 115.634613
# Config 1, Epoch 14800, Total Loss: 114.598679
# Config 1, Epoch 14900, Total Loss: 113.821159
# Config 1, Epoch 15000, Total Loss: 114.287506
# Config 1, Epoch 15100, Total Loss: 112.279442
# Config 1, Epoch 15200, Total Loss: 111.522835
# Config 1, Epoch 15300, Total Loss: 115.121574
# Config 1, Epoch 15400, Total Loss: 110.403915
# Config 1, Epoch 15500, Total Loss: 109.755020
# Config 1, Epoch 15600, Total Loss: 109.892723
# Config 1, Epoch 15700, Total Loss: 108.875946
# Config 1, Epoch 15800, Total Loss: 108.040627
# Config 1, Epoch 15900, Total Loss: 107.410645
# Config 1, Epoch 16000, Total Loss: 106.970406
# Config 1, Epoch 16100, Total Loss: 106.297478
# Config 1, Epoch 16200, Total Loss: 105.611191
# Config 1, Epoch 16300, Total Loss: 104.913147
# Config 1, Epoch 16400, Total Loss: 104.211754
# Config 1, Epoch 16500, Total Loss: 103.422234
# Config 1, Epoch 16600, Total Loss: 102.686501
# Config 1, Epoch 16700, Total Loss: 101.822250
# Config 1, Epoch 16800, Total Loss: 102.281662
# Config 1, Epoch 16900, Total Loss: 100.000740
# Config 1, Epoch 17000, Total Loss: 99.008972
# Config 1, Epoch 17100, Total Loss: 98.069344
# Config 1, Epoch 17200, Total Loss: 97.008133
# Config 1, Epoch 17300, Total Loss: 95.890541
# Config 1, Epoch 17400, Total Loss: 94.775124
# Config 1, Epoch 17500, Total Loss: 93.510246
# Config 1, Epoch 17600, Total Loss: 92.251137
# Config 1, Epoch 17700, Total Loss: 90.725235
# Config 1, Epoch 17800, Total Loss: 89.503441
# Config 1, Epoch 17900, Total Loss: 87.034058
# Config 1, Epoch 18000, Total Loss: 84.561638
# Config 1, Epoch 18100, Total Loss: 81.973953
# Config 1, Epoch 18200, Total Loss: 78.101440
# Config 1, Epoch 18300, Total Loss: 77.320320
# Config 1, Epoch 18400, Total Loss: 69.985825
# Config 1, Epoch 18500, Total Loss: 69.850388
# Config 1, Epoch 18600, Total Loss: 63.319542
# Config 1, Epoch 18700, Total Loss: 60.276073
# Config 1, Epoch 18800, Total Loss: 57.643822
# Config 1, Epoch 18900, Total Loss: 55.420780
# Config 1, Epoch 19000, Total Loss: 54.633369
# Config 1, Epoch 19100, Total Loss: 51.280529
# Config 1, Epoch 19200, Total Loss: 49.099709
# Config 1, Epoch 19300, Total Loss: 47.420460
# Config 1, Epoch 19400, Total Loss: 45.185535
# Config 1, Epoch 19500, Total Loss: 43.384338
# Config 1, Epoch 19600, Total Loss: 42.314049
# Config 1, Epoch 19700, Total Loss: 39.681332
# Config 1, Epoch 19800, Total Loss: 44.889946
# Config 1, Epoch 19900, Total Loss: 35.836910
# Config 1, Epoch 20000, Total Loss: 34.602558
# Config 1, Epoch 20100, Total Loss: 31.254509
# Config 1, Epoch 20200, Total Loss: 58.074722
# Config 1, Epoch 20300, Total Loss: 25.306761
# Config 1, Epoch 20400, Total Loss: 21.334532
# Config 1, Epoch 20500, Total Loss: 17.527815
# Config 1, Epoch 20600, Total Loss: 14.289020
# Config 1, Epoch 20700, Total Loss: 11.604671
# Config 1, Epoch 20800, Total Loss: 8.154518
# Config 1, Epoch 20900, Total Loss: 5.698640
# Config 1, Epoch 21000, Total Loss: 4.381776
# Config 1, Epoch 21100, Total Loss: 3.287751
# Config 1, Epoch 21200, Total Loss: 15.924993
# Config 1, Epoch 21300, Total Loss: 1.526279
# Config 1, Epoch 21400, Total Loss: 1.130819
# Config 1, Epoch 21500, Total Loss: 0.974447
# Config 1, Epoch 21600, Total Loss: 3.020536
# Config 1, Epoch 21700, Total Loss: 0.659071
# Config 1, Epoch 21800, Total Loss: 0.666328
# Config 1, Epoch 21900, Total Loss: 0.522560
# Config 1, Epoch 22000, Total Loss: 51.807095
# Config 1, Epoch 22100, Total Loss: 0.443168
# Config 1, Epoch 22200, Total Loss: 0.394767
# Config 1, Epoch 22300, Total Loss: 0.436529
# Config 1, Epoch 22400, Total Loss: 0.344973
# Config 1, Epoch 22500, Total Loss: 0.313061
# Config 1, Epoch 22600, Total Loss: 7.308388
# Config 1, Epoch 22700, Total Loss: 0.285390
# Config 1, Epoch 22800, Total Loss: 0.259958
# Config 1, Epoch 22900, Total Loss: 2.665834
# Config 1, Epoch 23000, Total Loss: 0.243066
# Config 1, Epoch 23100, Total Loss: 0.222722
# Config 1, Epoch 23200, Total Loss: 0.212362
# Config 1, Epoch 23300, Total Loss: 0.222163
# Config 1, Epoch 23400, Total Loss: 1.216412
# Config 1, Epoch 23500, Total Loss: 0.187350
# Config 1, Epoch 23600, Total Loss: 1.848639
# Config 1, Epoch 23700, Total Loss: 0.179081
# Config 1, Epoch 23800, Total Loss: 0.168745
# Config 1, Epoch 23900, Total Loss: 0.192940
# Config 1, Epoch 24000, Total Loss: 0.160927
# Config 1, Epoch 24100, Total Loss: 0.307213
# Config 1, Epoch 24200, Total Loss: 0.158377
# Config 1, Epoch 24300, Total Loss: 0.169761
# Config 1, Epoch 24400, Total Loss: 0.509087
# Config 1, Epoch 24500, Total Loss: 0.142975
# Config 1, Epoch 24600, Total Loss: 0.187011
# Config 1, Epoch 24700, Total Loss: 0.141951
# Config 1, Epoch 24800, Total Loss: 0.147280
# Config 1, Epoch 24900, Total Loss: 22.405201
# Config 1, Epoch 25000, Total Loss: 0.134177
# Config 1, Epoch 25100, Total Loss: 5.373566
# Config 1, Epoch 25200, Total Loss: 0.131984
# Config 1, Epoch 25300, Total Loss: 2.179181
# Config 1, Epoch 25400, Total Loss: 0.125806
# Config 1, Epoch 25500, Total Loss: 0.121307
# Config 1, Epoch 25600, Total Loss: 0.149045
# Config 1, Epoch 25700, Total Loss: 0.201408
# Config 1, Epoch 25800, Total Loss: 0.114989
# Config 1, Epoch 25900, Total Loss: 0.175253
# Config 1, Epoch 26000, Total Loss: 0.116072
# Config 1, Epoch 26100, Total Loss: 0.134978
# Config 1, Epoch 26200, Total Loss: 2.937851
# Config 1, Epoch 26300, Total Loss: 0.112332
# Config 1, Epoch 26400, Total Loss: 0.248471
# Config 1, Epoch 26500, Total Loss: 0.112733
# Config 1, Epoch 26600, Total Loss: 0.111287
# Config 1, Epoch 26700, Total Loss: 0.122339
# Config 1, Epoch 26800, Total Loss: 0.104423
# Config 1, Epoch 26900, Total Loss: 12.674239
# Config 1, Epoch 27000, Total Loss: 0.104940
# Config 1, Epoch 27100, Total Loss: 0.104682
# Config 1, Epoch 27200, Total Loss: 0.115847
# Config 1, Epoch 27300, Total Loss: 0.100042
# Config 1, Epoch 27400, Total Loss: 1.000578
# Config 1, Epoch 27500, Total Loss: 0.367968
# Config 1, Epoch 27600, Total Loss: 0.394899
# Config 1, Epoch 27700, Total Loss: 0.097064
# Config 1, Epoch 27800, Total Loss: 0.119343
# Config 1, Epoch 27900, Total Loss: 16.588831
# Config 1, Epoch 28000, Total Loss: 0.099171
# Config 1, Epoch 28100, Total Loss: 0.094027
# Config 1, Epoch 28200, Total Loss: 0.253555
# Config 1, Epoch 28300, Total Loss: 0.093224
# Config 1, Epoch 28400, Total Loss: 0.365787
# Config 1, Epoch 28500, Total Loss: 0.093576
# Config 1, Epoch 28600, Total Loss: 0.145221
# Config 1, Epoch 28700, Total Loss: 0.144755
# Config 1, Epoch 28800, Total Loss: 0.093057
# Config 1, Epoch 28900, Total Loss: 0.520726
# Config 1, Epoch 29000, Total Loss: 0.090683
# Config 1, Epoch 29100, Total Loss: 3.346619
# Config 1, Epoch 29200, Total Loss: 0.092029
# Config 1, Epoch 29300, Total Loss: 27.988819
# Config 1, Epoch 29400, Total Loss: 0.091820
# Config 1, Epoch 29500, Total Loss: 0.088761
# Config 1, Epoch 29600, Total Loss: 1.416853
# Config 1, Epoch 29700, Total Loss: 0.092372
# Config 1, Epoch 29800, Total Loss: 0.482266
# Config 1, Epoch 29900, Total Loss: 0.085959
# Best model for Config 1 saved with loss: 0.085435
#
# === Training for Config 2 ===
# TF: <TransferFunction>: sys[4132]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# s^2 - 3 s - 4
# -------------
# s^2 + 5 s + 6
#
# Config 2, Epoch 0, Total Loss: 14.257465
# Config 2, Epoch 100, Total Loss: 11.923040
# Config 2, Epoch 200, Total Loss: 11.915823
# Config 2, Epoch 300, Total Loss: 11.909750
# Config 2, Epoch 400, Total Loss: 11.901679
# Config 2, Epoch 500, Total Loss: 11.896199
# Config 2, Epoch 600, Total Loss: 11.892677
# Config 2, Epoch 700, Total Loss: 11.887816
# Config 2, Epoch 800, Total Loss: 11.886233
# Config 2, Epoch 900, Total Loss: 11.882001
# Config 2, Epoch 1000, Total Loss: 11.882151
# Config 2, Epoch 1100, Total Loss: 11.877743
# Config 2, Epoch 1200, Total Loss: 11.881083
# Config 2, Epoch 1300, Total Loss: 11.874821
# Config 2, Epoch 1400, Total Loss: 11.870475
# Config 2, Epoch 1500, Total Loss: 11.887224
# Config 2, Epoch 1600, Total Loss: 11.868919
# Config 2, Epoch 1700, Total Loss: 11.864035
# Config 2, Epoch 1800, Total Loss: 11.858558
# Config 2, Epoch 1900, Total Loss: 11.865878
# Config 2, Epoch 2000, Total Loss: 11.858320
# Config 2, Epoch 2100, Total Loss: 11.851645
# Config 2, Epoch 2200, Total Loss: 12.319158
# Config 2, Epoch 2300, Total Loss: 11.845564
# Config 2, Epoch 2400, Total Loss: 11.828011
# Config 2, Epoch 2500, Total Loss: 11.795638
# Config 2, Epoch 2600, Total Loss: 11.799896
# Config 2, Epoch 2700, Total Loss: 11.739689
# Config 2, Epoch 2800, Total Loss: 11.626571
# Config 2, Epoch 2900, Total Loss: 11.441446
# Config 2, Epoch 3000, Total Loss: 11.167451
# Config 2, Epoch 3100, Total Loss: 10.828695
# Config 2, Epoch 3200, Total Loss: 10.705509
# Config 2, Epoch 3300, Total Loss: 11.019492
# Config 2, Epoch 3400, Total Loss: 10.305169
# Config 2, Epoch 3500, Total Loss: 10.228018
# Config 2, Epoch 3600, Total Loss: 10.123241
# Config 2, Epoch 3700, Total Loss: 10.021821
# Config 2, Epoch 3800, Total Loss: 9.904579
# Config 2, Epoch 3900, Total Loss: 9.889507
# Config 2, Epoch 4000, Total Loss: 9.772079
# Config 2, Epoch 4100, Total Loss: 9.725625
# Config 2, Epoch 4200, Total Loss: 9.690557
# Config 2, Epoch 4300, Total Loss: 9.669451
# Config 2, Epoch 4400, Total Loss: 9.644140
# Config 2, Epoch 4500, Total Loss: 9.622093
# Config 2, Epoch 4600, Total Loss: 9.596868
# Config 2, Epoch 4700, Total Loss: 9.560567
# Config 2, Epoch 4800, Total Loss: 9.493902
# Config 2, Epoch 4900, Total Loss: 9.377584
# Config 2, Epoch 5000, Total Loss: 9.249237
# Config 2, Epoch 5100, Total Loss: 9.160941
# Config 2, Epoch 5200, Total Loss: 9.093858
# Config 2, Epoch 5300, Total Loss: 9.016681
# Config 2, Epoch 5400, Total Loss: 8.857413
# Config 2, Epoch 5500, Total Loss: 8.751747
# Config 2, Epoch 5600, Total Loss: 8.657328
# Config 2, Epoch 5700, Total Loss: 8.604032
# Config 2, Epoch 5800, Total Loss: 8.546864
# Config 2, Epoch 5900, Total Loss: 8.487814
# Config 2, Epoch 6000, Total Loss: 8.444265
# Config 2, Epoch 6100, Total Loss: 8.395531
# Config 2, Epoch 6200, Total Loss: 8.338524
# Config 2, Epoch 6300, Total Loss: 8.369518
# Config 2, Epoch 6400, Total Loss: 8.172117
# Config 2, Epoch 6500, Total Loss: 8.044972
# Config 2, Epoch 6600, Total Loss: 7.883953
# Config 2, Epoch 6700, Total Loss: 7.755996
# Config 2, Epoch 6800, Total Loss: 7.635985
# Config 2, Epoch 6900, Total Loss: 7.547012
# Config 2, Epoch 7000, Total Loss: 7.469733
# Config 2, Epoch 7100, Total Loss: 7.404561
# Config 2, Epoch 7200, Total Loss: 7.358190
# Config 2, Epoch 7300, Total Loss: 7.297620
# Config 2, Epoch 7400, Total Loss: 7.228283
# Config 2, Epoch 7500, Total Loss: 7.160237
# Config 2, Epoch 7600, Total Loss: 7.084041
# Config 2, Epoch 7700, Total Loss: 6.987236
# Config 2, Epoch 7800, Total Loss: 6.883111
# Config 2, Epoch 7900, Total Loss: 6.792419
# Config 2, Epoch 8000, Total Loss: 6.717620
# Config 2, Epoch 8100, Total Loss: 6.686808
# Config 2, Epoch 8200, Total Loss: 6.612251
# Config 2, Epoch 8300, Total Loss: 6.590599
# Config 2, Epoch 8400, Total Loss: 6.487827
# Config 2, Epoch 8500, Total Loss: 6.427922
# Config 2, Epoch 8600, Total Loss: 6.353806
# Config 2, Epoch 8700, Total Loss: 6.285518
# Config 2, Epoch 8800, Total Loss: 7.125955
# Config 2, Epoch 8900, Total Loss: 6.120316
# Config 2, Epoch 9000, Total Loss: 6.269203
# Config 2, Epoch 9100, Total Loss: 5.990692
# Config 2, Epoch 9200, Total Loss: 5.938908
# Config 2, Epoch 9300, Total Loss: 5.883090
# Config 2, Epoch 9400, Total Loss: 5.828312
# Config 2, Epoch 9500, Total Loss: 5.767369
# Config 2, Epoch 9600, Total Loss: 5.697843
# Config 2, Epoch 9700, Total Loss: 5.634926
# Config 2, Epoch 9800, Total Loss: 5.568766
# Config 2, Epoch 9900, Total Loss: 5.545827
# Config 2, Epoch 10000, Total Loss: 5.525351
# Config 2, Epoch 10100, Total Loss: 5.429156
# Config 2, Epoch 10200, Total Loss: 5.390984
# Config 2, Epoch 10300, Total Loss: 5.348482
# Config 2, Epoch 10400, Total Loss: 5.346610
# Config 2, Epoch 10500, Total Loss: 5.274640
# Config 2, Epoch 10600, Total Loss: 5.242302
# Config 2, Epoch 10700, Total Loss: 5.202781
# Config 2, Epoch 10800, Total Loss: 5.174332
# Config 2, Epoch 10900, Total Loss: 5.140688
# Config 2, Epoch 11000, Total Loss: 5.121344
# Config 2, Epoch 11100, Total Loss: 5.089466
# Config 2, Epoch 11200, Total Loss: 5.371980
# Config 2, Epoch 11300, Total Loss: 5.021098
# Config 2, Epoch 11400, Total Loss: 4.982314
# Config 2, Epoch 11500, Total Loss: 4.960806
# Config 2, Epoch 11600, Total Loss: 4.915790
# Config 2, Epoch 11700, Total Loss: 4.855722
# Config 2, Epoch 11800, Total Loss: 4.805481
# Config 2, Epoch 11900, Total Loss: 4.749691
# Config 2, Epoch 12000, Total Loss: 4.702349
# Config 2, Epoch 12100, Total Loss: 4.654546
# Config 2, Epoch 12200, Total Loss: 4.617962
# Config 2, Epoch 12300, Total Loss: 4.566086
# Config 2, Epoch 12400, Total Loss: 4.510618
# Config 2, Epoch 12500, Total Loss: 4.473987
# Config 2, Epoch 12600, Total Loss: 4.418602
# Config 2, Epoch 12700, Total Loss: 4.359655
# Config 2, Epoch 12800, Total Loss: 4.330165
# Config 2, Epoch 12900, Total Loss: 4.285102
# Config 2, Epoch 13000, Total Loss: 4.249665
# Config 2, Epoch 13100, Total Loss: 4.254521
# Config 2, Epoch 13200, Total Loss: 4.211228
# Config 2, Epoch 13300, Total Loss: 4.193222
# Config 2, Epoch 13400, Total Loss: 4.177071
# Config 2, Epoch 13500, Total Loss: 4.247859
# Config 2, Epoch 13600, Total Loss: 4.149470
# Config 2, Epoch 13700, Total Loss: 4.133486
# Config 2, Epoch 13800, Total Loss: 4.116520
# Config 2, Epoch 13900, Total Loss: 4.104862
# Config 2, Epoch 14000, Total Loss: 4.084757
# Config 2, Epoch 14100, Total Loss: 4.064104
# Config 2, Epoch 14200, Total Loss: 4.047088
# Config 2, Epoch 14300, Total Loss: 4.022693
# Config 2, Epoch 14400, Total Loss: 4.006428
# Config 2, Epoch 14500, Total Loss: 3.980929
# Config 2, Epoch 14600, Total Loss: 3.953851
# Config 2, Epoch 14700, Total Loss: 3.935969
# Config 2, Epoch 14800, Total Loss: 3.905323
# Config 2, Epoch 14900, Total Loss: 3.873721
# Config 2, Epoch 15000, Total Loss: 3.913709
# Config 2, Epoch 15100, Total Loss: 3.809349
# Config 2, Epoch 15200, Total Loss: 3.770375
# Config 2, Epoch 15300, Total Loss: 3.729388
# Config 2, Epoch 15400, Total Loss: 3.691599
# Config 2, Epoch 15500, Total Loss: 3.650922
# Config 2, Epoch 15600, Total Loss: 3.805290
# Config 2, Epoch 15700, Total Loss: 3.549339
# Config 2, Epoch 15800, Total Loss: 3.471620
# Config 2, Epoch 15900, Total Loss: 3.383001
# Config 2, Epoch 16000, Total Loss: 3.214902
# Config 2, Epoch 16100, Total Loss: 3.021181
# Config 2, Epoch 16200, Total Loss: 2.850372
# Config 2, Epoch 16300, Total Loss: 2.745149
# Config 2, Epoch 16400, Total Loss: 2.685223
# Config 2, Epoch 16500, Total Loss: 2.640596
# Config 2, Epoch 16600, Total Loss: 2.606935
# Config 2, Epoch 16700, Total Loss: 2.574913
# Config 2, Epoch 16800, Total Loss: 2.540569
# Config 2, Epoch 16900, Total Loss: 2.507808
# Config 2, Epoch 17000, Total Loss: 2.470723
# Config 2, Epoch 17100, Total Loss: 2.434515
# Config 2, Epoch 17200, Total Loss: 2.406691
# Config 2, Epoch 17300, Total Loss: 2.379578
# Config 2, Epoch 17400, Total Loss: 2.355464
# Config 2, Epoch 17500, Total Loss: 2.333132
# Config 2, Epoch 17600, Total Loss: 2.312022
# Config 2, Epoch 17700, Total Loss: 2.282115
# Config 2, Epoch 17800, Total Loss: 2.257692
# Config 2, Epoch 17900, Total Loss: 2.221785
# Config 2, Epoch 18000, Total Loss: 2.185621
# Config 2, Epoch 18100, Total Loss: 2.150201
# Config 2, Epoch 18200, Total Loss: 2.109107
# Config 2, Epoch 18300, Total Loss: 2.882925
# Config 2, Epoch 18400, Total Loss: 2.025748
# Config 2, Epoch 18500, Total Loss: 2.004198
# Config 2, Epoch 18600, Total Loss: 1.954238
# Config 2, Epoch 18700, Total Loss: 1.919493
# Config 2, Epoch 18800, Total Loss: 2.354076
# Config 2, Epoch 18900, Total Loss: 1.855501
# Config 2, Epoch 19000, Total Loss: 1.812609
# Config 2, Epoch 19100, Total Loss: 1.778180
# Config 2, Epoch 19200, Total Loss: 1.717015
# Config 2, Epoch 19300, Total Loss: 1.787138
# Config 2, Epoch 19400, Total Loss: 1.578424
# Config 2, Epoch 19500, Total Loss: 1.487021
# Config 2, Epoch 19600, Total Loss: 1.447948
# Config 2, Epoch 19700, Total Loss: 1.390457
# Config 2, Epoch 19800, Total Loss: 1.345738
# Config 2, Epoch 19900, Total Loss: 1.347136
# Best model for Config 2 saved with loss: 1.296426

# %%
# Plot Training Loss for Each Configuration Separately
for config, losses in loss_history.items():
    plt.figure(figsize=(8, 5))
    plt.plot(losses, label=f"Config {config}")
    plt.title(f"Training Loss for Config {config}")
    plt.xlabel("Epochs")
    plt.ylabel("Total Loss")
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# # 4. Evaluation and Visualization

# %%
# Evaluation loop for all configurations
configs = [0, 1, 2]
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

for config in configs:
    print(f"\n=== Evaluating Model for Config {config} ===")

    # Load the best model
    model_path = f"pinn_config{config}_best_model.pth"
    input_dim = 2  # [t, u]
    output_dim = 2 if config == 1 else 1  # [y1, y2] for Config 1, otherwise [y]
    pinn = PINN(input_dim=input_dim, output_dim=output_dim, hidden_size=50, num_layers=4).to(device)
    pinn.load_state_dict(torch.load(model_path))
    pinn.eval()

    # Load the test dataset
    _, _, test_dataset = load_pinn_dataset(config)

    # Fetch a sample from the test dataset
    sample = test_dataset[0]  # You can loop through the dataset if needed
    t = torch.tensor(sample['t'], requires_grad=True, dtype=torch.float32).to(device)
    u = torch.tensor(sample['u'], dtype=torch.float32).to(device)

    # Forward pass
    inputs = torch.cat((t.unsqueeze(1), u.unsqueeze(1)), dim=1)
    outputs = pinn(inputs)

    # For Config 1, split predictions into y1 and y2
    if config == 1:
        y1_pred = outputs[:, 0].detach().cpu().numpy()
        y2_pred = outputs[:, 1].detach().cpu().numpy()
        y1_true = sample['y1']
        y2_true = sample['y2']
        y_pred = y1_pred + y2_pred
        y_true = y1_true + y2_true
    else:
        y_pred = outputs[:, 0].detach().cpu().numpy()
        y_true = sample['y']

    # Plot predictions vs. ground truth
    plt.figure(figsize=(10, 6))
    plt.plot(sample['t'], y_true, label="Ground Truth (y_true)", linestyle="--")
    plt.plot(sample['t'], y_pred, label="Prediction (y_pred)", linestyle="-")
    plt.title(f"Config {config} - Test Results")
    plt.xlabel("Time")
    plt.ylabel("Response")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Print evaluation summary
    mse = np.mean((y_pred - y_true)**2)
    print(f"Config {config} - Mean Squared Error: {mse:.6f}")
# Out:
# === Evaluating Model for Config 0 ===
# C:\Users\ivanf\AppData\Local\Temp\ipykernel_13032\3578870312.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pinn.load_state_dict(torch.load(model_path))
# Config 0 - Mean Squared Error: 0.000243
#
# === Evaluating Model for Config 1 ===
# Config 1 - Mean Squared Error: 0.903361
#
# === Evaluating Model for Config 2 ===
# Config 2 - Mean Squared Error: 0.908485

# %%
# Evaluation loop for all configurations with impulse input
configs = [0, 1, 2]
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

for config in configs:
    print(f"\n=== Evaluating Model for Config {config} with Impulse Input ===")

    # Load the best model
    model_path = f"pinn_config{config}_best_model.pth"
    input_dim = 2  # [t, u]
    output_dim = 2 if config == 1 else 1  # [y1, y2] for Config 1, otherwise [y]
    pinn = PINN(input_dim=input_dim, output_dim=output_dim, hidden_size=50, num_layers=4).to(device)
    pinn.load_state_dict(torch.load(model_path))
    pinn.eval()

    # Generate impulse input using DataGenerator
    data_generator = DataGenerator(config, sampling_rate=100, time_length=10, initial_zero=2)
    impulse_data = data_generator.impulse_response(ampl=10, silent=True)
    t = torch.tensor(impulse_data['time'], requires_grad=True, dtype=torch.float32).to(device)
    u = torch.tensor(impulse_data['input'], dtype=torch.float32).to(device)

    # Forward pass
    inputs = torch.cat((t.unsqueeze(1), u.unsqueeze(1)), dim=1)
    outputs = pinn(inputs)

    # For Config 1, split predictions into y1 and y2
    if config == 1:
        y1_pred = outputs[:, 0].detach().cpu().numpy()
        y2_pred = outputs[:, 1].detach().cpu().numpy()
        y1_true = impulse_data['response_1']
        y2_true = impulse_data['response_2']
        y_pred = y1_pred + y2_pred
        y_true = y1_true + y2_true
    else:
        y_pred = outputs[:, 0].detach().cpu().numpy()
        y_true = impulse_data['response']

    # Plot predictions vs. ground truth
    plt.figure(figsize=(10, 6))
    plt.plot(impulse_data['time'], y_true, label="Ground Truth (y_true)", linestyle="--")
    plt.plot(impulse_data['time'], y_pred, label="Prediction (y_pred)", linestyle="-")
    plt.title(f"Config {config} - Test Results with Impulse Input")
    plt.xlabel("Time")
    plt.ylabel("Response")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Print evaluation summary
    mse = np.mean((y_pred - y_true)**2)
    print(f"Config {config} - Mean Squared Error (Impulse Input): {mse:.6f}")
# Out:
# === Evaluating Model for Config 0 with Impulse Input ===
# TF: <TransferFunction>: sys[4142]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#        4
# ---------------
# s^2 + 1.2 s + 4
# C:\Users\ivanf\AppData\Local\Temp\ipykernel_13032\3163432609.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pinn.load_state_dict(torch.load(model_path))
# Config 0 - Mean Squared Error (Impulse Input): 0.001200
#
# === Evaluating Model for Config 1 with Impulse Input ===
# TF: <TransferFunction>: sys[4164]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#          53 s^2 + 92.4 s + 392
# ----------------------------------------
# s^4 + 9.6 s^3 + 63.08 s^2 + 92.4 s + 196
# Config 1 - Mean Squared Error (Impulse Input): 0.376699
#
# === Evaluating Model for Config 2 with Impulse Input ===
# TF: <TransferFunction>: sys[4184]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# s^2 - 3 s - 4
# -------------
# s^2 + 5 s + 6
# Config 2 - Mean Squared Error (Impulse Input): 0.485851
